# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, Ridge
from sklearn.metrics import classification_report, mean_squared_error as mse, r2_score as r2
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      15 from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
#      16 from sklearn.metrics import confusion_matrix
# ---> 17 import seaborn as sns
#      18 import matplotlib.pyplot as plt
#      19 from sklearn.model_selection import GridSearchCV
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# # Preprocessing

# %%
x_df = pd.read_csv(r'C:\Training\Demo\Python\pytorch training\ml mini project\datasets\winequality_red_x_train.csv')
y_df = pd.read_csv(r'C:\Training\Demo\Python\pytorch training\ml mini project\datasets\winequality_red_y_train.csv')

# %%
def reverse_ohe(row):
    if row['3'] == 1:
        return 3
    elif row['4'] == 1:
        return 4
    elif row['5'] == 1:
        return 5
    elif row['6'] == 1:
        return 6
    elif row['7'] == 1:
        return 7
    elif row['8'] == 1:
        return 8
y_df['label'] = y_df.apply(reverse_ohe, axis=1)
y_df
# Out:
#       3  4  5  6  7  8  label
# 0     0  0  0  1  0  0      6
# 1     0  0  0  1  0  0      6
# 2     0  0  1  0  0  0      5
# 3     0  0  0  0  1  0      7
# 4     0  0  1  0  0  0      5
# ...  .. .. .. .. .. ..    ...
# 1066  0  0  0  1  0  0      6
# 1067  0  0  0  1  0  0      6
# 1068  0  0  1  0  0  0      5
# 1069  0  0  0  0  1  0      7
# 1070  0  0  0  1  0  0      6
#
# [1071 rows x 7 columns]

# %%
#split training and testing set 
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df['label'], test_size=0.2, random_state=0)

# %%
y_train.value_counts()
# Out:
# 5    360
# 6    349
# 7    101
# 4     28
# 8     11
# 3      7
# Name: label, dtype: int64

# %% [markdown]
# # Model Selection

# %%
models = [
    LogisticRegression(), 
    MLPClassifier(), 
    KNeighborsClassifier(), 
    SVC(),
    GaussianProcessClassifier(), 
    QuadraticDiscriminantAnalysis(), 
    DecisionTreeClassifier(), 
    RandomForestClassifier(), 
    AdaBoostClassifier(), 
    GaussianNB()
]

# %%
for model in models:
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    print('\n\n\n' + str(model))
    #show the results in a confusion matrix
    # cf_matrix = confusion_matrix(y_test, y_pred)

    # disp_cf = sns.heatmap(cf_matrix, annot=True, cmap='Blues', fmt='d')

    # disp_cf.set_title('Confusion Matrix')
    # disp_cf.set_xlabel('\nPredicted Category')
    # disp_cf.set_ylabel('Actual Category ')
    # plt.show()

    print(classification_report(y_test, y_pred))
# Out:
# LogisticRegression()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.73      0.75      0.74       104
#            6       0.51      0.68      0.58        76
#            7       0.50      0.11      0.18        28
#
#     accuracy                           0.62       215
#    macro avg       0.35      0.31      0.30       215
# weighted avg       0.60      0.62      0.59       215
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:679: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# MLPClassifier()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.74      0.68      0.71       104
#            6       0.51      0.70      0.59        76
#            7       0.60      0.32      0.42        28
#
#     accuracy                           0.62       215
#    macro avg       0.37      0.34      0.34       215
# weighted avg       0.62      0.62      0.61       215
#
#
#
#
# KNeighborsClassifier()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.58      0.68      0.63       104
#            6       0.49      0.51      0.50        76
#            7       0.62      0.29      0.39        28
#
#     accuracy                           0.55       215
#    macro avg       0.34      0.30      0.30       215
# weighted avg       0.53      0.55      0.53       215
#
#
#
#
# SVC()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.70      0.74      0.72       104
#            6       0.53      0.68      0.60        76
#            7       1.00      0.25      0.40        28
#
#     accuracy                           0.63       215
#    macro avg       0.45      0.33      0.34       215
# weighted avg       0.66      0.63      0.61       215
#
#
#
#
# GaussianProcessClassifier()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.71      0.77      0.74       104
#            6       0.51      0.66      0.57        76
#            7       0.33      0.04      0.06        28
#
#     accuracy                           0.61       215
#    macro avg       0.31      0.29      0.27       215
# weighted avg       0.56      0.61      0.57       215
#
#
#
#
# QuadraticDiscriminantAnalysis()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.70      0.55      0.61       104
#            6       0.48      0.67      0.56        76
#            7       0.64      0.50      0.56        28
#
#     accuracy                           0.57       215
#    macro avg       0.36      0.34      0.35       215
# weighted avg       0.59      0.57      0.57       215
#
#
#
#
# DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.40      0.33      0.36         6
#            5       0.68      0.62      0.65       104
#            6       0.53      0.59      0.56        76
#            7       0.48      0.50      0.49        28
#            8       0.00      0.00      0.00         0
#
#     accuracy                           0.58       215
#    macro avg       0.35      0.34      0.34       215
# weighted avg       0.59      0.58      0.58       215
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# RandomForestClassifier()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.75      0.78      0.76       104
#            6       0.61      0.75      0.67        76
#            7       0.93      0.46      0.62        28
#
#     accuracy                           0.70       215
#    macro avg       0.46      0.40      0.41       215
# weighted avg       0.70      0.70      0.69       215
#
#
#
#
# AdaBoostClassifier()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.63      0.73      0.68       104
#            6       0.43      0.54      0.48        76
#            7       0.00      0.00      0.00        28
#
#     accuracy                           0.54       215
#    macro avg       0.21      0.25      0.23       215
# weighted avg       0.46      0.54      0.50       215
#
#
#
#
# GaussianNB()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         6
#            5       0.74      0.61      0.67       104
#            6       0.48      0.55      0.52        76
#            7       0.43      0.46      0.45        28
#            8       0.00      0.00      0.00         0
#
#     accuracy                           0.55       215
#    macro avg       0.28      0.27      0.27       215
# weighted avg       0.59      0.55      0.56       215
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Training\Demo\Python\pytorch training\ml mini project\env\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Hyperparameter Tuning
#
# ### RandomForest hyperparameter tuning

# %%
log_model = LogisticRegression()

# %%
param_grid = [    
    {'penalty' : ['l1', 'l2', 'elasticnet', 'none'],
    # 'C' : np.logspace(-4, 4, 5),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    # 'max_iter' : [100, 1000,2500, 5000]
    }
]


clf = GridSearchCV(log_model, param_grid = param_grid, cv = 2, verbose=True, n_jobs=-1)
best_clf = clf.fit(x_train, y_train)
